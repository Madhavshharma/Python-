# %% [markdown]
# <p> numeric data analysis

# %%
import pandas as pd
import numpy as np

# %%
data=pd.read_csv("googleplaystore.csv").dropna()
data
# Out:
#                                                      App             Category  \
# 0         Photo Editor & Candy Camera & Grid & ScrapBook       ART_AND_DESIGN
# 1                                    Coloring book moana       ART_AND_DESIGN
# 2      U Launcher Lite – FREE Live Cool Themes, Hide ...       ART_AND_DESIGN
# 3                                  Sketch - Draw & Paint       ART_AND_DESIGN
# 4                  Pixel Draw - Number Art Coloring Book       ART_AND_DESIGN
# ...                                                  ...                  ...
# 10834                                      FR Calculator               FAMILY
# 10836                                   Sya9a Maroc - FR               FAMILY
# 10837                   Fr. Mike Schmitz Audio Teachings               FAMILY
# 10839                      The SCP Foundation DB fr nn5n  BOOKS_AND_REFERENCE
# 10840      iHoroscope - 2018 Daily Horoscope & Astrology            LIFESTYLE
#
# ...

# %%
# analysing the numeric column of the dataset 
data.describe()
# Out:
#             Rating
# count  9367.000000
# mean      4.193338
# std       0.537431
# min       1.000000
# 25%       4.000000
# 50%       4.300000
# 75%       4.500000
# max      19.000000

# %% [markdown]
# <p> first we will anlysis the ratings with null values

# %%
data["Rating"]
# Out:
# 0        4.1
# 1        3.9
# 2        4.7
# 3        4.5
# 4        4.3
#         ...
# 10836    4.5
# 10837    5.0
# 10838    NaN
# 10839    4.5
# 10840    4.5
# Name: Rating, Length: 10841, dtype: float64

# %% [markdown]
# <p>1.  findig the average ratings

# %%
int(sum(data['Rating']))/9360
# Out:
# 4.191773504273504

# %% [markdown]
# we can clearly see from the above that we cannogt convert the  Null values into integer that's why
# before analysing the data we need to remove all the null values

# %%
# removing the null values 
data.dropna()
# Out:
#                                                      App             Category  \
# 0         Photo Editor & Candy Camera & Grid & ScrapBook       ART_AND_DESIGN
# 1                                    Coloring book moana       ART_AND_DESIGN
# 2      U Launcher Lite – FREE Live Cool Themes, Hide ...       ART_AND_DESIGN
# 3                                  Sketch - Draw & Paint       ART_AND_DESIGN
# 4                  Pixel Draw - Number Art Coloring Book       ART_AND_DESIGN
# ...                                                  ...                  ...
# 10834                                      FR Calculator               FAMILY
# 10836                                   Sya9a Maroc - FR               FAMILY
# 10837                   Fr. Mike Schmitz Audio Teachings               FAMILY
# 10839                      The SCP Foundation DB fr nn5n  BOOKS_AND_REFERENCE
# 10840      iHoroscope - 2018 Daily Horoscope & Astrology            LIFESTYLE
#
# ...

# %%
# now analyzing the numeric column without null values 
average_rating=int(sum(data['Rating']))/len(data['Rating'])
average_rating
# Out:
# 4.191773504273504

# %%
#findign the average through different ways 
average_rating=str(sum(data['Rating'])/9360)[:4]
average_rating
# Out:
# '4.19'

# %%
s=0
for i in data['Rating']:
    s=s+i
print(s)
s/9360
# Out:
# 39235.60000000005
# 4.191837606837612

# %% [markdown]
# #### so the average ratings given by the users is 4.19

# %%
s=0
for i in data['Rating']:
    if(i>=5):
        s=s+i
print(s)
# Out:
# 1370.0

# %%
s=0
for i in data['Rating']:
    if(i==5.0):
        s=s+i
print(s)
# Out:
# 1370.0

# %%
s=0
for i in data['Rating']:
    if(i<=5):
        s=s+i
print(s)
# Out:
# 39235.60000000005

# %%
s=0
for i in data['Rating']:
    if(i>=4 and i<=4.5):
        s+=i
print(s)
# Out:
# 23329.399999999958
